# %% [markdown]
# # 고양이, 개 분류 - CNN v4
# - Dropout 추가
# - 이미지 중앙에 배치
# - 각 이미지를 10개씩 부풀려 파일로 저장하고 이 파일로 학습

# %%
import cv2, os
import numpy as np
from tqdm.notebook import tqdm
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2022-01-23 08:59:56--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.202.128, 64.233.183.128, 173.194.193.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.202.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   217MB/s    in 0.3s
#
# 2022-01-23 08:59:56 (217 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# !unzip cats_and_dogs_filtered.zip > /dev/null

# %% [markdown]
# - 데이터 탐색

# %%
# 이미지를 센터링해서 이미지를 리턴하는 함수
IMAGE_SIZE = 150

def center_image(img, format='Image'):
    if format == 'Image':               # 포맷이 필로우 이미지 타입이면,
        h, w, _ = np.array(img).shape
    else:                           # 포맷이 이미지가 아니고 , 넘파이의 어레이라면,
        h, w = img.shape[:-1]        
    if h > w:
        width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
    else:
        width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE

    new_img = np.array(img.resize((width,height)))

    diff = abs(width - height)//2
    if width > height:
        final_img = new_img[:, diff:diff+IMAGE_SIZE, :]
    else:
        final_img = new_img[diff:diff+IMAGE_SIZE, :, :]

    return Image.fromarray(final_img) if format == 'Image' else final_img
# 파이널 이미지의 타입은 넘파이의 어레이 였다.
# 뉴 이미지를 자른 것이므로 넘파이의 어레이. 그러므로 아래서 넘파이 어레이를 save하면 오류
# 넘파이는 세이브를 jiwon하지 않아.

# %%
CENTER_DIR = 'cats_and_dogs_centered'
train_dir = f'{CENTER_DIR}/train'
validation_dir = f'{CENTER_DIR}/validation'
train_cats_dir = f'{CENTER_DIR}/train/cats'
train_dogs_dir = f'{CENTER_DIR}/train/dogs'
validation_cats_dir = f'{CENTER_DIR}/validation/cats'
validation_dogs_dir = f'{CENTER_DIR}/validation/dogs'

# %%
if not os.path.exists(CENTER_DIR):
    os.mkdir(CENTER_DIR)
for dir in [train_dir, validation_dir, train_cats_dir, train_dogs_dir, validation_cats_dir, validation_dogs_dir]:
    os.mkdir(dir)

# %%
old_train_cats_dir = 'cats_and_dogs_filtered/train/cats'
old_train_dogs_dir = 'cats_and_dogs_filtered/train/dogs'
old_validation_cats_dir = 'cats_and_dogs_filtered/validation/cats'
old_validation_dogs_dir = 'cats_and_dogs_filtered/validation/dogs'

# %%
# cats_and_dogs_filtered -> image 축소/확대후 centering -> cats_and_dogs_centered
from glob import glob
for src_dir in [old_train_cats_dir,old_train_dogs_dir,old_validation_cats_dir,old_validation_dogs_dir]:
    dst_dir = src_dir.split('/')[1:]            # cats_and_dogs_filtered 제거
    dst_dir = '/'.join([CENTER_DIR] + dst_dir)  # CENTER_DIR 밑에 오는 디렉토리 지정
    for fname in glob(f'{src_dir}/*.jpg'):
        dst_fname = fname.split('/')[-1]    # 예를 들어, cat.475.jpg
        src_img = Image.open(fname)         # 사이즈가 제각각인 이미지
        dst_img = center_image(src_img)     # 150 x 150으로 centering된 이미지(pillow로 변경됨)
        dst_img.save(f'{dst_dir}/{dst_fname}')

# %% [markdown]
# - 이미지 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img

train_datagen = ImageDataGenerator(
    rescale=1/255.,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
for fname in tqdm(glob(f'{train_cats_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_cats_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
for fname in tqdm(glob(f'{train_dogs_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_dogs_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
len(os.listdir(train_cats_dir)), len(os.listdir(train_dogs_dir))
# Out:
# (10994, 10998)

# %%
plt.figure(figsize=(12,5))
cat_fnames = glob(f'{train_cats_dir}/*')
dog_fnames = glob(f'{train_dogs_dir}/*')
for i in range(5):
    img = Image.open(cat_fnames[i])
    plt.subplot(2,5,i+1)
    plt.imshow(img), plt.title(cat_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
    img = Image.open(dog_fnames[i])
    plt.subplot(2,5,i+1+5)
    plt.imshow(img), plt.title(dog_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# - 모델 구성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
validation_generator = test_datagen.flow_from_directory(
    validation_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 21992 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의 20으로 수정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v4.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=20)

# %% [markdown]
# - 모델 실행

# %%
hist = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    steps_per_epoch=100,        # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=50,        # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.69261, saving model to best-cat-dog-v4.h5
# 100/100 - 12s - loss: 0.9126 - accuracy: 0.4935 - val_loss: 0.6926 - val_accuracy: 0.5300 - 12s/epoch - 122ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss did not improve from 0.69261
# 100/100 - 11s - loss: 0.6990 - accuracy: 0.5265 - val_loss: 0.7084 - val_accuracy: 0.5130 - 11s/epoch - 106ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss did not improve from 0.69261
# 100/100 - 11s - loss: 0.6884 - accuracy: 0.5500 - val_loss: 0.7362 - val_accuracy: 0.5010 - 11s/epoch - 109ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.69261 to 0.63631, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.6600 - accuracy: 0.6115 - val_loss: 0.6363 - val_accuracy: 0.6260 - 11s/epoch - 110ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.63631 to 0.62723, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.6597 - accuracy: 0.6070 - val_loss: 0.6272 - val_accuracy: 0.6400 - 11s/epoch - 110ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.62723 to 0.61621, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.6335 - accuracy: 0.6480 - val_loss: 0.6162 - val_accuracy: 0.6600 - 11s/epoch - 107ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.61621 to 0.59716, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.6208 - accuracy: 0.6685 - val_loss: 0.5972 - val_accuracy: 0.6810 - 11s/epoch - 108ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 0.59716 to 0.59304, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.6010 - accuracy: 0.6790 - val_loss: 0.5930 - val_accuracy: 0.6830 - 11s/epoch - 110ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.59304
# 100/100 - 11s - loss: 0.5939 - accuracy: 0.6995 - val_loss: 0.5970 - val_accuracy: 0.6740 - 11s/epoch - 109ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.46365
# 100/100 - 11s - loss: 0.4487 - accuracy: 0.8015 - val_loss: 0.4799 - val_accuracy: 0.7600 - 11s/epoch - 106ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.46365
# 100/100 - 11s - loss: 0.4289 - accuracy: 0.8145 - val_loss: 0.4683 - val_accuracy: 0.7840 - 11s/epoch - 106ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.46365
# 100/100 - 11s - loss: 0.4296 - accuracy: 0.8155 - val_loss: 0.4825 - val_accuracy: 0.7830 - 11s/epoch - 105ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.46365
# 100/100 - 10s - loss: 0.4246 - accuracy: 0.8175 - val_loss: 0.4657 - val_accuracy: 0.7880 - 10s/epoch - 105ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss improved from 0.46365 to 0.46109, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.4393 - accuracy: 0.8255 - val_loss: 0.4611 - val_accuracy: 0.7940 - 11s/epoch - 106ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.46109
# 100/100 - 10s - loss: 0.4191 - accuracy: 0.8215 - val_loss: 0.4671 - val_accuracy: 0.7820 - 10s/epoch - 102ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.46109
# 100/100 - 10s - loss: 0.4207 - accuracy: 0.8140 - val_loss: 0.4842 - val_accuracy: 0.7870 - 10s/epoch - 101ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.46109
# 100/100 - 10s - loss: 0.3973 - accuracy: 0.8170 - val_loss: 0.5077 - val_accuracy: 0.7560 - 10s/epoch - 100ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.46109
# 100/100 - 10s - loss: 0.4192 - accuracy: 0.8150 - val_loss: 0.4761 - val_accuracy: 0.7910 - 10s/epoch - 102ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.46109
# 100/100 - 11s - loss: 0.4132 - accuracy: 0.8055 - val_loss: 0.5287 - val_accuracy: 0.7770 - 11s/epoch - 106ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss did not improve from 0.46109
# 100/100 - 11s - loss: 0.4204 - accuracy: 0.8105 - val_loss: 0.4777 - val_accuracy: 0.7710 - 11s/epoch - 105ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.46109
# 100/100 - 10s - loss: 0.4327 - accuracy: 0.8005 - val_loss: 0.4622 - val_accuracy: 0.7780 - 10s/epoch - 104ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.46109
# 100/100 - 11s - loss: 0.4260 - accuracy: 0.8125 - val_loss: 0.5870 - val_accuracy: 0.7330 - 11s/epoch - 106ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.46109
# 100/100 - 11s - loss: 0.4258 - accuracy: 0.8087 - val_loss: 0.4918 - val_accuracy: 0.7690 - 11s/epoch - 107ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.46109
# 100/100 - 11s - loss: 0.4211 - accuracy: 0.8115 - val_loss: 0.5018 - val_accuracy: 0.7710 - 11s/epoch - 110ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.46109
# 100/100 - 11s - loss: 0.4220 - accuracy: 0.8090 - val_loss: 0.5242 - val_accuracy: 0.7650 - 11s/epoch - 108ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss improved from 0.46109 to 0.45560, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.4207 - accuracy: 0.8250 - val_loss: 0.4556 - val_accuracy: 0.7840 - 11s/epoch - 106ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.45560
# 100/100 - 10s - loss: 0.4226 - accuracy: 0.8130 - val_loss: 0.4613 - val_accuracy: 0.7870 - 10s/epoch - 104ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss improved from 0.45560 to 0.44638, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.4236 - accuracy: 0.8095 - val_loss: 0.4464 - val_accuracy: 0.7940 - 11s/epoch - 106ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 0.44638 to 0.44376, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.4005 - accuracy: 0.8340 - val_loss: 0.4438 - val_accuracy: 0.7960 - 11s/epoch - 107ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.44376
# 100/100 - 11s - loss: 0.4115 - accuracy: 0.8100 - val_loss: 0.4514 - val_accuracy: 0.7960 - 11s/epoch - 108ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss did not improve from 0.44376
# 100/100 - 11s - loss: 0.4191 - accuracy: 0.8195 - val_loss: 0.4635 - val_accuracy: 0.7890 - 11s/epoch - 106ms/step
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.44376
# 100/100 - 11s - loss: 0.4108 - accuracy: 0.8250 - val_loss: 0.4620 - val_accuracy: 0.7740 - 11s/epoch - 105ms/step
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.44376
# 100/100 - 10s - loss: 0.4231 - accuracy: 0.8190 - val_loss: 0.4673 - val_accuracy: 0.7730 - 10s/epoch - 104ms/step
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.44376
# 100/100 - 10s - loss: 0.4030 - accuracy: 0.8270 - val_loss: 0.4520 - val_accuracy: 0.7840 - 10s/epoch - 104ms/step
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.44376
# 100/100 - 11s - loss: 0.4181 - accuracy: 0.8090 - val_loss: 0.4854 - val_accuracy: 0.7860 - 11s/epoch - 106ms/step
# Epoch 80/100
#
# Epoch 00080: val_loss improved from 0.44376 to 0.43264, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.4446 - accuracy: 0.8140 - val_loss: 0.4326 - val_accuracy: 0.8010 - 11s/epoch - 110ms/step
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.43264
# 100/100 - 10s - loss: 0.4059 - accuracy: 0.8300 - val_loss: 0.4833 - val_accuracy: 0.7590 - 10s/epoch - 105ms/step
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.43264
# 100/100 - 11s - loss: 0.4342 - accuracy: 0.8092 - val_loss: 0.4606 - val_accuracy: 0.8080 - 11s/epoch - 106ms/step
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.43264
# 100/100 - 10s - loss: 0.4120 - accuracy: 0.8265 - val_loss: 0.4639 - val_accuracy: 0.7910 - 10s/epoch - 104ms/step
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.43264
# 100/100 - 10s - loss: 0.4107 - accuracy: 0.8323 - val_loss: 0.4622 - val_accuracy: 0.7840 - 10s/epoch - 103ms/step
# Epoch 85/100
#
# Epoch 00085: val_loss improved from 0.43264 to 0.42826, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.4107 - accuracy: 0.8190 - val_loss: 0.4283 - val_accuracy: 0.8090 - 11s/epoch - 109ms/step
# Epoch 86/100
#
# Epoch 00086: val_loss improved from 0.42826 to 0.41825, saving model to best-cat-dog-v4.h5
# 100/100 - 11s - loss: 0.3863 - accuracy: 0.8358 - val_loss: 0.4183 - val_accuracy: 0.8100 - 11s/epoch - 110ms/step
# Epoch 87/100
#
# Epoch 00087: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.3779 - accuracy: 0.8449 - val_loss: 0.4645 - val_accuracy: 0.7900 - 11s/epoch - 109ms/step
# Epoch 88/100
#
# Epoch 00088: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.3998 - accuracy: 0.8248 - val_loss: 0.4484 - val_accuracy: 0.8200 - 11s/epoch - 110ms/step
# Epoch 89/100
#
# Epoch 00089: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4310 - accuracy: 0.8200 - val_loss: 0.4824 - val_accuracy: 0.7970 - 11s/epoch - 109ms/step
# Epoch 90/100
#
# Epoch 00090: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.3984 - accuracy: 0.8240 - val_loss: 0.4699 - val_accuracy: 0.7850 - 11s/epoch - 108ms/step
# Epoch 91/100
#
# Epoch 00091: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4147 - accuracy: 0.8283 - val_loss: 0.4670 - val_accuracy: 0.7860 - 11s/epoch - 107ms/step
# Epoch 92/100
#
# Epoch 00092: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4195 - accuracy: 0.8200 - val_loss: 0.4406 - val_accuracy: 0.8110 - 11s/epoch - 107ms/step
# Epoch 93/100
#
# Epoch 00093: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4168 - accuracy: 0.8180 - val_loss: 0.4527 - val_accuracy: 0.7880 - 11s/epoch - 106ms/step
# Epoch 94/100
#
# Epoch 00094: val_loss did not improve from 0.41825
# 100/100 - 10s - loss: 0.4115 - accuracy: 0.8250 - val_loss: 0.5152 - val_accuracy: 0.7680 - 10s/epoch - 103ms/step
# Epoch 95/100
#
# Epoch 00095: val_loss did not improve from 0.41825
# 100/100 - 10s - loss: 0.4095 - accuracy: 0.8230 - val_loss: 0.4601 - val_accuracy: 0.7900 - 10s/epoch - 104ms/step
# Epoch 96/100
#
# Epoch 00096: val_loss did not improve from 0.41825
# 100/100 - 10s - loss: 0.4053 - accuracy: 0.8180 - val_loss: 0.4842 - val_accuracy: 0.7870 - 10s/epoch - 105ms/step
# Epoch 97/100
#
# Epoch 00097: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4187 - accuracy: 0.8155 - val_loss: 0.4484 - val_accuracy: 0.8040 - 11s/epoch - 109ms/step
# Epoch 98/100
#
# Epoch 00098: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4071 - accuracy: 0.8230 - val_loss: 0.4677 - val_accuracy: 0.7970 - 11s/epoch - 108ms/step
# Epoch 99/100
#
# Epoch 00099: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.3844 - accuracy: 0.8275 - val_loss: 0.5630 - val_accuracy: 0.7910 - 11s/epoch - 108ms/step
# Epoch 100/100
#
# Epoch 00100: val_loss did not improve from 0.41825
# 100/100 - 11s - loss: 0.4002 - accuracy: 0.8175 - val_loss: 0.4548 - val_accuracy: 0.8000 - 11s/epoch - 110ms/step

# %%
# centering 만 했을 경우 : 0.6920  나  0.7320
# centering 과 augmentation 을 했을 경우 0.7900  나 8000 vest는 8100
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 테스트 이미지 분류

# %%
from google.colab import files

up = files.upload()
# Out:
#      <input type="file" id="files-fac8dfcc-c000-46ea-9315-33af2eb429af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fac8dfcc-c000-46ea-9315-33af2eb429af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# Saving dog1.jpg to dog1.jpg
# Saving dog2.jpg to dog2.jpg
# Saving puppy.jpg to puppy.jpg

# %%
for fname in up.keys():
    img = Image.open(fname)
    img = center_image(img)
    classes = best_model.predict(np.array(img).reshape(1,150,150,3))
    print(f"{classes[0,0]:.4f} {fname} is a {'dog' if classes[0,0] > 0.5 else 'cat'}")
# Out:
# 0.0000 cat.jpg is a cat
# 1.0000 dog1.jpg is a dog
# 0.0000 dog2.jpg is a cat
# 1.0000 puppy.jpg is a dog

# %% [markdown]
# - 학습과정 시각화

# %%
import numpy as np
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# 번외편. 맞게 하는건가?, early_stop를 걸치 않았어야 되는거겠지?

# %%
model1 = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model1.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
validation_generator = test_datagen.flow_from_directory(
    validation_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 21992 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의 다시 10 으로 수정 path v5 로수정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v5.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model1.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=300,       # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=5,        # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/300
#
# Epoch 00001: val_loss improved from inf to 0.59485, saving model to best-cat-dog-v5.h5
# 1100/1100 - 105s - loss: 0.6268 - accuracy: 0.6546 - val_loss: 0.5949 - val_accuracy: 0.6800 - 105s/epoch - 95ms/step
# Epoch 2/300
#
# Epoch 00002: val_loss did not improve from 0.59485
# 1100/1100 - 102s - loss: 0.5310 - accuracy: 0.7388 - val_loss: 0.6279 - val_accuracy: 0.6400 - 102s/epoch - 93ms/step
# Epoch 3/300
#
# Epoch 00003: val_loss improved from 0.59485 to 0.51959, saving model to best-cat-dog-v5.h5
# 1100/1100 - 102s - loss: 0.4820 - accuracy: 0.7705 - val_loss: 0.5196 - val_accuracy: 0.7200 - 102s/epoch - 93ms/step
# Epoch 4/300
#
# Epoch 00004: val_loss improved from 0.51959 to 0.44945, saving model to best-cat-dog-v5.h5
# 1100/1100 - 95s - loss: 0.4573 - accuracy: 0.7905 - val_loss: 0.4494 - val_accuracy: 0.8600 - 95s/epoch - 86ms/step
# Epoch 5/300
#
# Epoch 00005: val_loss improved from 0.44945 to 0.41201, saving model to best-cat-dog-v5.h5
# 1100/1100 - 75s - loss: 0.4324 - accuracy: 0.8055 - val_loss: 0.4120 - val_accuracy: 0.8000 - 75s/epoch - 68ms/step
# Epoch 6/300
#
# Epoch 00006: val_loss did not improve from 0.41201
# 1100/1100 - 74s - loss: 0.4159 - accuracy: 0.8118 - val_loss: 0.4321 - val_accuracy: 0.8100 - 74s/epoch - 67ms/step
# Epoch 7/300
#
# Epoch 00007: val_loss did not improve from 0.41201
# 1100/1100 - 73s - loss: 0.4080 - accuracy: 0.8210 - val_loss: 0.4128 - val_accuracy: 0.8400 - 73s/epoch - 67ms/step
# Epoch 8/300
#
# Epoch 00008: val_loss improved from 0.41201 to 0.37296, saving model to best-cat-dog-v5.h5
# 1100/1100 - 74s - loss: 0.4051 - accuracy: 0.8247 - val_loss: 0.3730 - val_accuracy: 0.8300 - 74s/epoch - 67ms/step
# Epoch 9/300
#
# Epoch 00009: val_loss did not improve from 0.37296
# 1100/1100 - 74s - loss: 0.4003 - accuracy: 0.8268 - val_loss: 0.5521 - val_accuracy: 0.8100 - 74s/epoch - 67ms/step
# Epoch 10/300
#
# Epoch 00010: val_loss did not improve from 0.37296
# 1100/1100 - 74s - loss: 0.4051 - accuracy: 0.8292 - val_loss: 0.6738 - val_accuracy: 0.6800 - 74s/epoch - 67ms/step
# Epoch 11/300
#
# Epoch 00011: val_loss did not improve from 0.37296
# 1100/1100 - 76s - loss: 0.4019 - accuracy: 0.8306 - val_loss: 0.5923 - val_accuracy: 0.6600 - 76s/epoch - 69ms/step
# Epoch 12/300
#
# Epoch 00012: val_loss did not improve from 0.37296
# 1100/1100 - 77s - loss: 0.4093 - accuracy: 0.8275 - val_loss: 0.5689 - val_accuracy: 0.7600 - 77s/epoch - 70ms/step
# Epoch 13/300
#
# Epoch 00013: val_loss did not improve from 0.37296
# 1100/1100 - 84s - loss: 0.4134 - accuracy: 0.8278 - val_loss: 0.5084 - val_accuracy: 0.7400 - 84s/epoch - 76ms/step
# Epoch 14/300
#
# Epoch 00014: val_loss improved from 0.37296 to 0.32082, saving model to best-cat-dog-v5.h5
# 1100/1100 - 87s - loss: 0.4134 - accuracy: 0.8258 - val_loss: 0.3208 - val_accuracy: 0.8800 - 87s/epoch - 79ms/step
# Epoch 15/300
#
# Epoch 00015: val_loss did not improve from 0.32082
# 1100/1100 - 87s - loss: 0.4202 - accuracy: 0.8263 - val_loss: 0.8190 - val_accuracy: 0.7700 - 87s/epoch - 79ms/step
# Epoch 16/300
#
# Epoch 00016: val_loss did not improve from 0.32082
# 1100/1100 - 88s - loss: 0.4172 - accuracy: 0.8257 - val_loss: 0.6466 - val_accuracy: 0.6600 - 88s/epoch - 80ms/step
# Epoch 17/300
#
# Epoch 00017: val_loss did not improve from 0.32082
# 1100/1100 - 87s - loss: 0.4333 - accuracy: 0.8187 - val_loss: 0.6248 - val_accuracy: 0.6900 - 87s/epoch - 79ms/step
# Epoch 18/300
#
# Epoch 00018: val_loss did not improve from 0.32082
# 1100/1100 - 86s - loss: 0.4336 - accuracy: 0.8214 - val_loss: 0.5283 - val_accuracy: 0.7400 - 86s/epoch - 79ms/step
# Epoch 19/300
#
# Epoch 00019: val_loss did not improve from 0.32082
# 1100/1100 - 87s - loss: 0.4401 - accuracy: 0.8127 - val_loss: 0.5749 - val_accuracy: 0.6900 - 87s/epoch - 79ms/step
# Epoch 20/300
#
# Epoch 00020: val_loss did not improve from 0.32082
# 1100/1100 - 88s - loss: 0.4423 - accuracy: 0.8122 - val_loss: 0.5165 - val_accuracy: 0.7800 - 88s/epoch - 80ms/step
# Epoch 21/300
#
# Epoch 00021: val_loss did not improve from 0.32082
# 1100/1100 - 87s - loss: 0.4460 - accuracy: 0.8113 - val_loss: 0.5502 - val_accuracy: 0.7300 - 87s/epoch - 79ms/step
# Epoch 22/300
#
# Epoch 00022: val_loss did not improve from 0.32082
# 1100/1100 - 86s - loss: 0.4527 - accuracy: 0.8092 - val_loss: 0.5304 - val_accuracy: 0.6300 - 86s/epoch - 79ms/step
# Epoch 23/300
#
# Epoch 00023: val_loss did not improve from 0.32082
# 1100/1100 - 87s - loss: 0.4524 - accuracy: 0.8080 - val_loss: 0.5512 - val_accuracy: 0.6700 - 87s/epoch - 79ms/step
# Epoch 24/300
#
# Epoch 00024: val_loss did not improve from 0.32082
# 1100/1100 - 86s - loss: 0.4510 - accuracy: 0.8107 - val_loss: 0.5989 - val_accuracy: 0.6800 - 86s/epoch - 78ms/step

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 학습과정 시각화 Model 1

# %%
y_acc = hist.history['accuracy']
y_loss = hist.history['loss']
y_vacc = hist.history['val_accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
_, ax0 = plt.subplots(figsize=(12,8))
ax1 = ax0.twinx()
ax0.plot(xs, y_loss, label='train loss')
ax0.plot(xs, y_vloss, label='validation loss')
ax0.set_ylabel('loss')
ax1.plot(xs, y_acc, c='darkgreen', label='train accuracy')
ax1.plot(xs, y_vacc, c='magenta', label='validation accuracy')
ax1.set_ylabel('accuracy')
ax0.set_xlabel('Epoch')
ax0.legend(), ax1.legend()
plt.grid()
plt.show()
