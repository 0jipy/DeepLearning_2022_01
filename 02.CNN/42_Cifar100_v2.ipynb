# %% [markdown]
# # Cifar-100 ver2  이미지분류 - 업그레이드 적기
#
#
# - Cifar 100 용 별도 모델
# - 32/64/128 Conv2D node 수
# - Adam() optimizer 사용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar100
(X_train, y_train), (X_test,y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 2s 0us/step
# 169017344/169001437 [==============================] - 2s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# 컬러, 50000 데이터 테스트는 1만
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 
    'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 
    'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 
    'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster' 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion',
    'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse',
    'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear',
    'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine',
    'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose',
    'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake',
    'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table',
    'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
    'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman',
    'worm'
]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
for i in range(40):
    plt.subplot(4,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()
# 1주제당 500개 이미지

# %%
# X_data : 0~1 사이의 실수 (float32) 로 변환
# X_train = X_train.astype(float32) / 255.   or X_train = X_train / 255. ==> 64비트 실수
X_train = X_train.astype('float32') / 255.
X_test  = X_test.astype(np.float32) / 255.

# %%
# y_data : One-hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)
Y_train.shape, Y_test.shape
# Out:
# ((50000, 100), (10000, 100))

# %% [markdown]
# ## 모델 정의 / 설정 / 학습 / 평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    MaxPooling2D(),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.1),
    Conv2D(128, (3,3), padding='same', activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(100, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 8, 8, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 1,193,636
# Trainable params: 1,193,636
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss= 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
model_path = 'best-cifar100-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks = [checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 3.47445, saving model to best-cifar100-v2.h5
# 1250/1250 - 13s - loss: 4.0323 - accuracy: 0.0809 - val_loss: 3.4744 - val_accuracy: 0.1715 - 13s/epoch - 10ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 3.47445 to 3.09140, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 3.3894 - accuracy: 0.1851 - val_loss: 3.0914 - val_accuracy: 0.2493 - 4s/epoch - 3ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 3.09140 to 2.78956, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 3.0544 - accuracy: 0.2471 - val_loss: 2.7896 - val_accuracy: 0.3017 - 4s/epoch - 3ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 2.78956 to 2.62094, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.8399 - accuracy: 0.2864 - val_loss: 2.6209 - val_accuracy: 0.3412 - 4s/epoch - 3ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 2.62094 to 2.55007, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.6728 - accuracy: 0.3185 - val_loss: 2.5501 - val_accuracy: 0.3591 - 4s/epoch - 3ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 2.55007 to 2.46540, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.5445 - accuracy: 0.3465 - val_loss: 2.4654 - val_accuracy: 0.3781 - 4s/epoch - 3ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 2.46540 to 2.38889, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.4418 - accuracy: 0.3634 - val_loss: 2.3889 - val_accuracy: 0.3980 - 4s/epoch - 3ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 2.38889 to 2.33327, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.3483 - accuracy: 0.3875 - val_loss: 2.3333 - val_accuracy: 0.4000 - 4s/epoch - 3ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 2.33327
# 1250/1250 - 4s - loss: 2.2724 - accuracy: 0.3990 - val_loss: 2.3376 - val_accuracy: 0.4050 - 4s/epoch - 3ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 2.33327 to 2.31385, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.2014 - accuracy: 0.4164 - val_loss: 2.3138 - val_accuracy: 0.4084 - 4s/epoch - 3ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 2.31385 to 2.24863, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.1327 - accuracy: 0.4308 - val_loss: 2.2486 - val_accuracy: 0.4264 - 4s/epoch - 3ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 2.24863 to 2.23283, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 2.0783 - accuracy: 0.4394 - val_loss: 2.2328 - val_accuracy: 0.4244 - 4s/epoch - 3ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 2.23283
# 1250/1250 - 4s - loss: 2.0218 - accuracy: 0.4518 - val_loss: 2.2466 - val_accuracy: 0.4248 - 4s/epoch - 3ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 2.23283
# 1250/1250 - 4s - loss: 1.9780 - accuracy: 0.4610 - val_loss: 2.2402 - val_accuracy: 0.4236 - 4s/epoch - 3ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 2.23283
# 1250/1250 - 4s - loss: 1.9376 - accuracy: 0.4724 - val_loss: 2.2667 - val_accuracy: 0.4230 - 4s/epoch - 3ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss did not improve from 2.23283
# 1250/1250 - 4s - loss: 1.8910 - accuracy: 0.4809 - val_loss: 2.2345 - val_accuracy: 0.4253 - 4s/epoch - 3ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 2.23283 to 2.22617, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 1.8505 - accuracy: 0.4912 - val_loss: 2.2262 - val_accuracy: 0.4322 - 4s/epoch - 3ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 2.22617 to 2.22599, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 1.8113 - accuracy: 0.4976 - val_loss: 2.2260 - val_accuracy: 0.4342 - 4s/epoch - 3ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 2.22599 to 2.22191, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 1.7839 - accuracy: 0.5028 - val_loss: 2.2219 - val_accuracy: 0.4337 - 4s/epoch - 3ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 2.22191
# 1250/1250 - 4s - loss: 1.7518 - accuracy: 0.5117 - val_loss: 2.2228 - val_accuracy: 0.4367 - 4s/epoch - 3ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 2.22191
# 1250/1250 - 4s - loss: 1.7175 - accuracy: 0.5195 - val_loss: 2.2636 - val_accuracy: 0.4315 - 4s/epoch - 3ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 2.22191
# 1250/1250 - 4s - loss: 1.6984 - accuracy: 0.5266 - val_loss: 2.2450 - val_accuracy: 0.4397 - 4s/epoch - 3ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 2.22191
# 1250/1250 - 4s - loss: 1.6562 - accuracy: 0.5336 - val_loss: 2.2480 - val_accuracy: 0.4312 - 4s/epoch - 3ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 2.22191
# 1250/1250 - 4s - loss: 1.6419 - accuracy: 0.5398 - val_loss: 2.2268 - val_accuracy: 0.4373 - 4s/epoch - 3ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 2.22191
# 1250/1250 - 4s - loss: 1.6259 - accuracy: 0.5418 - val_loss: 2.2485 - val_accuracy: 0.4362 - 4s/epoch - 3ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 2.22191 to 2.21686, saving model to best-cifar100-v2.h5
# 1250/1250 - 4s - loss: 1.5920 - accuracy: 0.5508 - val_loss: 2.2169 - val_accuracy: 0.4402 - 4s/epoch - 3ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.5833 - accuracy: 0.5552 - val_loss: 2.2300 - val_accuracy: 0.4436 - 4s/epoch - 3ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.5518 - accuracy: 0.5579 - val_loss: 2.2803 - val_accuracy: 0.4351 - 4s/epoch - 3ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.5282 - accuracy: 0.5666 - val_loss: 2.2355 - val_accuracy: 0.4400 - 4s/epoch - 4ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.5331 - accuracy: 0.5660 - val_loss: 2.2710 - val_accuracy: 0.4366 - 4s/epoch - 4ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.5091 - accuracy: 0.5692 - val_loss: 2.2369 - val_accuracy: 0.4458 - 4s/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.4800 - accuracy: 0.5799 - val_loss: 2.2893 - val_accuracy: 0.4385 - 4s/epoch - 3ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 2.21686
# 1250/1250 - 5s - loss: 1.4857 - accuracy: 0.5783 - val_loss: 2.2628 - val_accuracy: 0.4357 - 5s/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.4666 - accuracy: 0.5832 - val_loss: 2.2687 - val_accuracy: 0.4439 - 4s/epoch - 3ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.4505 - accuracy: 0.5850 - val_loss: 2.2844 - val_accuracy: 0.4407 - 4s/epoch - 3ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 2.21686
# 1250/1250 - 4s - loss: 1.4362 - accuracy: 0.5874 - val_loss: 2.3046 - val_accuracy: 0.4347 - 4s/epoch - 3ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test,Y_test)
313/313 [==============================] - 1s 3ms/step - loss: 2.1970 - accuracy: 0.4409
[2.197026491165161, 0.4408999979496002]
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 2.1970 - accuracy: 0.4409
# [2.197026491165161, 0.4408999979496002]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
