# %% [markdown]
# # 고양이, 개 분류 - CNN v3
# - Dropout 추가
# - Kaggle에서 'Copy API Command'를 사용하여 API key를 발급받을 것
# - pull data 로 수행

# %% [markdown]
# - 데이터 다운로드 및 압축 해제 훈련/테스트 데이터 분리

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-4c8940d3-d1c1-444e-9a34-1525cc834ec3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4c8940d3-d1c1-444e-9a34-1525cc834ec3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
import json, os
with open('kaggle.json') as f:
    kaggle = json.load(f)
os.environ['KAGGLE_USERNAME'] = kaggle['username'] # username from json file
os.environ['KAGGLE_KEY'] = kaggle['key']    # key from the json file

# %%
# !kaggle datasets download -d shaunthesheep/microsoft-catsvsdogs-dataset
# Out:
# Downloading microsoft-catsvsdogs-dataset.zip to /content
#  98% 774M/788M [00:23<00:00, 31.9MB/s]
# 100% 788M/788M [00:23<00:00, 35.2MB/s]

# %%
# !unzip microsoft-catsvsdogs-dataset.zip > /dev/null

# %%
cat_dir = 'PetImages/Cat'
os.unlink(f'{cat_dir}/Thumbs.db')   # 지우는법 # 썸브.db지움
cat_list = os.listdir(cat_dir)
len(cat_list)
# Out:
# 12500

# %%
dog_dir = 'PetImages/Dog'
os.unlink(f'{dog_dir}/Thumbs.db')
dog_list = os.listdir(dog_dir)
len(dog_list)
# Out:
# 12500

# %%
# Destination directory
train_dir = 'PetImages/train'
test_dir  = 'PetImages/test'
train_cats_dir = f'{train_dir}/cats'
train_dogs_dir = f'{train_dir}/dogs'
test_cats_dir  = f'{test_dir}/cats'
test_dogs_dir  = f'{test_dir}/dogs'

# %%
for dir_name in [train_dir,test_dir,train_cats_dir,train_dogs_dir,test_cats_dir,test_dogs_dir]:
    if not os.path.exists(dir_name):
        os.mkdir(dir_name)

# %%
for file in cat_list:
    if len(file) < 9:           # train data
        os.rename(f'{cat_dir}/{file}', f'{train_cats_dir}/{file}')
    else:                       # test data
        os.rename(f'{cat_dir}/{file}', f'{test_cats_dir}/{file}')

# %%
len(os.listdir(cat_dir)), len(os.listdir(train_cats_dir)), len(os.listdir(test_cats_dir))
# Out:
# (0, 10000, 2500)

# %%
for file in dog_list:
    if len(file) < 9:           # train data
        os.rename(f'{dog_dir}/{file}', f'{train_dogs_dir}/{file}')
    else:                       # test data
        os.rename(f'{dog_dir}/{file}', f'{test_dogs_dir}/{file}')

# %%
len(os.listdir(dog_dir)), len(os.listdir(train_dogs_dir)), len(os.listdir(test_dogs_dir))
# Out:
# (0, 10000, 2500)

# %%
os.rmdir(cat_dir)
os.rmdir(dog_dir)

# %% [markdown]
# ## 데이터 탐색

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# 파일 이름
test_cats_fnames = os.listdir(test_cats_dir)
test_dogs_fnames = os.listdir(test_dogs_dir)

print(test_cats_fnames[:5])
print(test_dogs_fnames[:5])
# Out:
# ['10851.jpg', '11613.jpg', '10898.jpg', '11350.jpg', '12122.jpg']
# ['10851.jpg', '11613.jpg', '10898.jpg', '11350.jpg', '12122.jpg']

# %%
# 파일 갯수
train_cats_fnames = os.listdir(train_cats_dir)
train_dogs_fnames = os.listdir(train_dogs_dir)
len(train_cats_fnames), len(train_dogs_fnames)
# Out:
# (10000, 10000)

# %% [markdown]
# - 이미지 파일 에러 찾기

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# 어느 파일에서 에러가 발생했는지 알아보는 코드
from PIL import Image
import glob
try:
    for fname in glob.glob(f'{test_cats_dir}/*.jpg'):
        img = Image.open(fname)
except:
    print(fname)

# %%
# dogs 오류
try:
    for fname in glob.glob(f'{train_dogs_dir}/*.jpg'):
        img = Image.open(fname)
except:
    print(fname)

# %%
# cats/666.jpg 이미지에 에러가 있어, 12000.jpg 파일로 대체
# dogs/11702.jpg 이미지에 에러가 있어, 12000.jpg 파일로 대체
# !cp PetImages/test/cats/12000.jpg PetImages/train/cats/666.jpg
# !cp PetImages/test/dogs/12000.jpg PetImages/test/dogs/11702.jpg

# %%
# !ls -l PetImeges/test/cats/12000.jpg PetImage/train/cats/666.jpg
# Out:
# ls: cannot access 'PetImeges/test/cats/12000.jpg': No such file or directory
# ls: cannot access 'PetImage/train/cats/666.jpg': No such file or directory

# %% [markdown]
# - 모델 정의

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-6),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
test_generator = test_datagen.flow_from_directory(
    test_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v3.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 모델 실행

# %%
hist = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=100,
    steps_per_epoch=1000,        # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=250,        # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.52249, saving model to best-cat-dog-v3.h5
# 1000/1000 - 72s - loss: 0.6138 - accuracy: 0.6630 - val_loss: 0.5225 - val_accuracy: 0.7424 - 72s/epoch - 72ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss did not improve from 0.52249
# 1000/1000 - 62s - loss: 0.5310 - accuracy: 0.7376 - val_loss: 0.6384 - val_accuracy: 0.6798 - 62s/epoch - 62ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.52249 to 0.48680, saving model to best-cat-dog-v3.h5
# 1000/1000 - 62s - loss: 0.4920 - accuracy: 0.7632 - val_loss: 0.4868 - val_accuracy: 0.7796 - 62s/epoch - 62ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.48680 to 0.44547, saving model to best-cat-dog-v3.h5
# 1000/1000 - 62s - loss: 0.4695 - accuracy: 0.7829 - val_loss: 0.4455 - val_accuracy: 0.7962 - 62s/epoch - 62ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.44547 to 0.43850, saving model to best-cat-dog-v3.h5
# 1000/1000 - 63s - loss: 0.4559 - accuracy: 0.7915 - val_loss: 0.4385 - val_accuracy: 0.8078 - 63s/epoch - 63ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 0.43850 to 0.42495, saving model to best-cat-dog-v3.h5
# 1000/1000 - 63s - loss: 0.4415 - accuracy: 0.8035 - val_loss: 0.4249 - val_accuracy: 0.8080 - 63s/epoch - 63ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.42495 to 0.39357, saving model to best-cat-dog-v3.h5
# 1000/1000 - 62s - loss: 0.4300 - accuracy: 0.8098 - val_loss: 0.3936 - val_accuracy: 0.8202 - 62s/epoch - 62ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.39357
# 1000/1000 - 62s - loss: 0.4275 - accuracy: 0.8098 - val_loss: 0.4265 - val_accuracy: 0.8166 - 62s/epoch - 62ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.39357
# 1000/1000 - 62s - loss: 0.4190 - accuracy: 0.8181 - val_loss: 0.4359 - val_accuracy: 0.8100 - 62s/epoch - 62ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.39357
# 1000/1000 - 63s - loss: 0.4074 - accuracy: 0.8245 - val_loss: 0.4623 - val_accuracy: 0.7874 - 63s/epoch - 63ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.39357
# 1000/1000 - 63s - loss: 0.4136 - accuracy: 0.8209 - val_loss: 0.4319 - val_accuracy: 0.7958 - 63s/epoch - 63ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.39357
# 1000/1000 - 63s - loss: 0.4100 - accuracy: 0.8229 - val_loss: 0.4085 - val_accuracy: 0.8224 - 63s/epoch - 63ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.39357
# 1000/1000 - 63s - loss: 0.4128 - accuracy: 0.8233 - val_loss: 0.4069 - val_accuracy: 0.8296 - 63s/epoch - 63ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.39357
# 1000/1000 - 63s - loss: 0.4140 - accuracy: 0.8240 - val_loss: 0.4733 - val_accuracy: 0.7648 - 63s/epoch - 63ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.39357
# 1000/1000 - 63s - loss: 0.4081 - accuracy: 0.8254 - val_loss: 0.4638 - val_accuracy: 0.7644 - 63s/epoch - 63ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.39357 to 0.38689, saving model to best-cat-dog-v3.h5
# 1000/1000 - 62s - loss: 0.4155 - accuracy: 0.8252 - val_loss: 0.3869 - val_accuracy: 0.8382 - 62s/epoch - 62ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.38689
# 1000/1000 - 62s - loss: 0.4136 - accuracy: 0.8230 - val_loss: 0.4819 - val_accuracy: 0.7748 - 62s/epoch - 62ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.38689
# 1000/1000 - 62s - loss: 0.4176 - accuracy: 0.8221 - val_loss: 0.4245 - val_accuracy: 0.8208 - 62s/epoch - 62ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.38689
# 1000/1000 - 62s - loss: 0.4241 - accuracy: 0.8206 - val_loss: 0.4228 - val_accuracy: 0.8034 - 62s/epoch - 62ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.38689 to 0.38064, saving model to best-cat-dog-v3.h5
# 1000/1000 - 62s - loss: 0.4276 - accuracy: 0.8213 - val_loss: 0.3806 - val_accuracy: 0.8434 - 62s/epoch - 62ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4287 - accuracy: 0.8191 - val_loss: 0.4288 - val_accuracy: 0.8018 - 62s/epoch - 62ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4308 - accuracy: 0.8187 - val_loss: 0.3949 - val_accuracy: 0.8370 - 62s/epoch - 62ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4322 - accuracy: 0.8127 - val_loss: 0.4953 - val_accuracy: 0.7400 - 62s/epoch - 62ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4346 - accuracy: 0.8183 - val_loss: 0.4723 - val_accuracy: 0.7780 - 62s/epoch - 62ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4378 - accuracy: 0.8128 - val_loss: 0.4299 - val_accuracy: 0.7914 - 62s/epoch - 62ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4331 - accuracy: 0.8181 - val_loss: 0.4242 - val_accuracy: 0.8106 - 62s/epoch - 62ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4424 - accuracy: 0.8134 - val_loss: 0.4524 - val_accuracy: 0.8132 - 62s/epoch - 62ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4408 - accuracy: 0.8133 - val_loss: 0.5432 - val_accuracy: 0.6724 - 62s/epoch - 62ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4461 - accuracy: 0.8165 - val_loss: 0.5345 - val_accuracy: 0.6914 - 62s/epoch - 62ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.38064
# 1000/1000 - 62s - loss: 0.4467 - accuracy: 0.8134 - val_loss: 0.4504 - val_accuracy: 0.8134 - 62s/epoch - 62ms/step

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 테스트 이미지 분류

# %%
from google.colab import files

up = files.upload()
# Out:
#      <input type="file" id="files-b0a1da97-fb9d-4340-98c8-f21427d2d5f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0a1da97-fb9d-4340-98c8-f21427d2d5f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg
# Saving dog1.jpg to dog1.jpg
# Saving dog2.jpg to dog2.jpg
# Saving puppy.jpg to puppy.jpg

# %%
img = cv2.imread('cat.jpg')[:,:,::-1]
plt.imshow(img), plt.title(img.shape[:-1]);

# %%
# 150 x 150 size
img = cv2.resize(img, dsize=(150,150), interpolation=cv2.INTER_AREA)
plt.imshow(img);

# %%
best_model.predict(img.reshape(1,150,150,3))
# Out:
# array([[0.9998185]], dtype=float32)

# %%
for fname in up.keys():
    img = cv2.imread(fname)[:,:,::-1]
    if sum(img.shape[:-1]) > 300:       # 150 x 150 보다 큰 이미지
        img = cv2.resize(img, dsize=(150,150), interpolation=cv2.INTER_AREA)
    else:
        img = cv2.resize(img, dsize=(150,150), interpolation=cv2.INTER_CUBIC)
    classes = best_model.predict(img.reshape(1,150,150,3))
    print(f"{classes[0,0]:.4f} {fname} is a {'dog' if classes[0,0] > 0.5 else 'cat'}")
# Out:
# 0.9998 cat.jpg is a dog
# 1.0000 dog1.jpg is a dog
# 1.0000 dog2.jpg is a dog
# 1.0000 puppy.jpg is a dog

# %% [markdown]
# - 학습과정 시각화

# %%
import numpy as np
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
